# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score , mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
data = datasets.load_diabetes()
x = data['data']
y = data['target']

# %%
df = pd.DataFrame(data['data'] , columns=data['feature_names'])
df['target'] = data['target']

# %%
df.head(10)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0
# 5 -0.076395 -0.041176 -0.096346    97.0
# 6 -0.039493 -0.062917 -0.038357   138.0
# 7  0.017703 -0.035816  0.003064    63.0
# 8 -0.002592 -0.014960  0.011349   110.0
# 9 -0.002592  0.067737 -0.013504   310.0

# %%
# Out:
#                 age       sex       bmi        bp        s1        s2  \
#  0.000000  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821
#  1.000000  0.000000 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
#  2.000000  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194
#  3.000000  0.000000 -0.044642 -0.011595 -0.036656  0.012191  0.024991
#  4.000000  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
# ...             ...       ...       ...       ...       ...       ...
# -0.089063  0.000000       NaN       NaN       NaN       NaN       NaN
# -0.092695  0.000000       NaN       NaN       NaN       NaN       NaN
# -0.045472  0.000000       NaN       NaN       NaN       NaN       NaN
# -0.070900  0.000000       NaN       NaN       NaN       NaN       NaN
# -0.096328  0.000000       NaN       NaN       NaN       NaN       NaN
#
#                  s3        s4        s5        s6  target
#  0.000000 -0.043401 -0.002592  0.019907 -0.017646   151.0
#  1.000000  0.074412 -0.039493 -0.068332 -0.092204    75.0
#  2.000000 -0.032356 -0.002592  0.002861 -0.025930   141.0
#  3.000000 -0.036038  0.034309  0.022688 -0.009362   206.0
#  4.000000  0.008142 -0.002592 -0.031988 -0.046641   135.0
# ...             ...       ...       ...       ...     ...
# -0.089063       NaN       NaN       NaN       NaN     NaN
# -0.092695       NaN       NaN       NaN       NaN     NaN
# -0.045472       NaN       NaN       NaN       NaN     NaN
# -0.070900       NaN       NaN       NaN       NaN     NaN
# -0.096328       NaN       NaN       NaN       NaN     NaN
#
# [448 rows x 11 columns]

# %%
xtrain , xtest , ytrain , ytest = train_test_split(x,y,test_size=.3,random_state=12)

# %%
model = LinearRegression().fit(xtrain , ytrain)
ypred = model.predict(xtest)

# %%
plt.scatter(ytest , ypred)

# %%
MSE = mean_squared_error(ytest , ypred)
MAE = mean_absolute_error(ytest , ypred)
print(f"mean squared error is {MSE} and mean absolute error is {MAE}")
# Out:
# mean squared error is 3157.5734769951277 and mean absolute error is 45.36351421267708
